# %% [markdown]
# <a href="https://colab.research.google.com/github/adnanagbaria/MLcourse/blob/main/class2_promptEng.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This file has prompts for Class2

# %%
# prompt: Create two sets of data, size=50 range from 1 to 100, call them control and treatment

import numpy as np

control = np.random.randint(1, 101, size=50)
treatment = np.random.randint(1, 101, size=50)

print("Control group data:", control)
print("Treatment group data:", treatment)
# Out:
# Control group data: [49 34 74 48 89 69  6 81 14 86 71 59 16 25 25 78  9 16  3 41 15  6 25 30
#  97 80 69 96 17 43  4 62 60 39 81 91 88 70 80 14 25 84  9 39 74 41 38 29
#  15 69]
# Treatment group data: [ 57  82  69  59  42  25   9  19   7  39  33  68  70  78  65  20  31  83
#   40   7  57   4  38   8  43  25  53  71  42  92  87  42 100  28  52   4
#   91  27  40  31  35  20  27  79  63  58  47  27  36  81]

# %%
# prompt: Plot the distribution of the data. Frequency vs value, and show the means

import numpy as np
import matplotlib.pyplot as plt
# Plotting the distribution for the control group
plt.figure(figsize=(10, 5))
plt.hist(control, bins=20, alpha=0.7, label='Control', color='skyblue')
plt.axvline(np.mean(control), color='blue', linestyle='dashed', linewidth=2, label=f'Control Mean: {np.mean(control):.2f}')
# Plotting the distribution for the treatment group
plt.hist(treatment, bins=20, alpha=0.7, label='Treatment', color='lightcoral')
plt.axvline(np.mean(treatment), color='red', linestyle='dashed', linewidth=2, label=f'Treatment Mean: {np.mean(treatment):.2f}')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Distribution of Control and Treatment Groups')
plt.legend()
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
# prompt: calculate t-statistic

from scipy import stats

t_statistic, p_value = stats.ttest_ind(control, treatment)

print(f"T-statistic: {t_statistic:.4f}")
print(f"P-value: {p_value:.4f}")
# Out:
# T-statistic: 0.2580
# P-value: 0.7970

# %%
# prompt: mount to my google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
sample_data = "/content/drive/MyDrive/Colab Notebooks/sigma/ML/samples.csv"

# %%
# prompt: read sample_data from a csv file from google drive

import pandas as pd

df = pd.read_csv(sample_data)
print(df.head())
# Out:
#    Sample1  Sample2
# 0       20       68
# 1       23       87
# 2       28        4
# 3       78       18
# 4       20       61
